# %% [markdown]
# # OCR解决方案分析

# %% [markdown]
# ## 1） [Tesseract-OCR](https://github.com/tesseract-ocr)—— 谷歌开源的光学识别引擎

# %% [markdown]
# 优点：开源，自己服务器部署，且有较快的识别速度，和较不错的识别效果

# %% [markdown]
# 缺点：中文识别效果差，针对中文需要大量训练建立字库

# %% [markdown]
# ## 2） [Baidu-OCR](https://cloud.baidu.com/product/ocr/general) —— 百度文字识别api

# %% [markdown]
# 优点：基于深度学习，有庞大的中文字库，中文识别效果非常不错，识别速度快，价格目前较低

# %% [markdown]
# 缺点：英文会把大写字母识别成小写字母，需要改正，导致英文识别效果一般

# %% [markdown]
# 识别特点：采用从上至下逐行扫描的方式

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/td.png" align="left" />

# %% [markdown]
# 附价格表：

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/bdocr_price.png" align="left" />

# %% [markdown]
# <br/><br/>

# %% [markdown]
# ## 场景分析

# %% [markdown]
# ### 场景I —— 英语教材单页

# %% [markdown]
# 样张：

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/yyl1.jpg" align="left" width="600" height="480" />

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/yyl2.jpg" align="left" width="600" height="480" />

# %% [markdown]
# ==================================================================
#
# 特点：<br/>
# <p>①色彩众多，背景复杂，难以识别确定文本区域</p>
# <p>②文本区域多</p>
# <p>③字体颜色不一</p>

# %% [markdown]
# 解决思路：<br/>
# <p>这里由于 ⑴识别英文 ⑵文本区域多块 的需要，考虑使用**人工划分文本区域** 配合 **Tesseract-OCR** 完成</p>

# %% [markdown]
# ***识别结果：***

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/scan1.jpg" align="left" />

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/scan2.jpg" align="left" />

# %% [markdown]
# ==================================================================
#
# 此场景感觉可以连同点读划区域时一起完成。<br/>
#
# 识别率较高，操作人员只需要做少量的纠正修改。但是人工选择区域的时候需要尽量选择干净的背景，不然会导致识别率降低。<br/>
#
# 针对这种划分多文本区域，识别纯英文文本的，不适合调用百度api，一来不够准确，二来成本较高<br/>
#
# 经大量检验，***未经训练的Tesseract-OCR仅适用于纯英文的情况。*** <br/><br/>

# %% [markdown]
# ### 场景II —— 语文教材单页、教辅碎片

# %% [markdown]
# 教材样张：

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/ywl1.jpg" align="left"  width="600" height="480 "/>

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/ywl2.jpg" align="left"  width="600" height="480"/>

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/ywl3.jpg" align="left"  width="600" height="480 "/>

# %% [markdown]
# ==================================================================
#
# 特点：
#
# 图片较大，字数众多，竖直陈列，文字背景干净

# %% [markdown]
# 解决思路：
#
# 这里由于 ①纯中文 ②结构整齐，适合使用百度通用文字识别api（分块或整页）

# %% [markdown]
# ### *识别结果：*

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/scan3.jpg" align="left" />

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/scan5.jpg" align="left" />

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/scan6.jpg" align="left" />

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/scan7.jpg" align="left" />

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/scan8.jpg" align="left" />

# %% [markdown]
#  <br/><br/><br/>

# %% [markdown]
# 教辅碎片样张：

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/ywjl1.jpg" align="left" width="500" height="390" />

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/ywjl2.jpg" align="left" width="600" height="480"/>

# %% [markdown]
# <br/><br/>
# ### *识别结果：*

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/scan9.jpg" align="left" width="760" height="580" />

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/scan10.jpg" align="left" width="760" height="580" />

# %% [markdown]
# ==================================================================
#
# 百度识别api在识别中文时表现得非常好，识别率很高，无论在整页或是分块识别，效果都非常好。<br/>
#
# ***语文类的教材、教辅适合用百度api进行识别。*** <br/><br/>

# %% [markdown]
# ### 场景III —— 英语教辅碎片

# %% [markdown]
# 样张：

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/yyjl1.jpg" align="left" width="600" height="400"/>

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/yyjl2.jpg" align="left" width="600" height="400" />

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/yyjl3.jpg" align="left" width="600" height="400" />

# %% [markdown]
# ==================================================================
#
# 特点：<br/>
# <p>①中英文混合（中文只有题目开头，占少量，大多数识别的是英文）</p>
# <p>②许多文本结构整体不整齐，有些需要分块</p>
# <p>③有以下干扰OCR识别的问题：<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;I. 穿插着有图片干扰<br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;II. 遇到括号和下划线时，无法很好识别，甚至会影响当行后面的识别（如长答题下划线后面的文本）
# </p>

# %% [markdown]
# ==================================================================
#
# <p>使用百度OCR识别英语教辅碎片时，遇到了以下问题：</p>
#
# <p>⑴很多时候会把大写字母识别成小写，但是也是正确的小写字母</p>
#
# <p>⑵无法很好地识别题目的下划线  _______________</p>
#
# <p>⑶无法很好地识别选择题的选项 如：A. at school &nbsp;&nbsp;&nbsp; B. at home &nbsp;&nbsp;&nbsp; C. at 10:00<br/>
# 因为选项间有太大空白，百度会把他识别成换行</p>
#
# ==================================================================

# %% [markdown]
# <p>这里我针对第一个问题，首先对百度返回的结果进行了优化。</p><br/>
#
# ### *识别结果：*

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/yyj1.png"  align="left"/>

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/yyj2.png"  align="left" width="800" height="500"/>

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/yyj3.png"  align="left" width="900" height="300"/>

# %% [markdown]
# ====================================================================
#
# 这里对百度OCR返回结果的优化，看起来非常不错，把他识别出来的一些本该是大写的小写字母，转换成了大写，一些多余的空格做了剔除；
#
# 目前看来，优化后无论是中英文，都有非常高的识别率，可以满足我们的要求。

# %% [markdown]
#   <br/><br/>

# %% [markdown]
# ### 场景IV —— 数学教辅碎片

# %% [markdown]
# 样张：

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/sxjl1.jpg" align="left" width="300" height="210" />

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/sxjl2.jpg" align="left" width="300" height="210"/>

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/sxjl3.jpg" align="left" width="600" height="480" />

# %% [markdown]
# ### *识别结果：*

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/sxj1.png" align="left" width="480" height="360" />

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/sxj2.png" align="left" width="600" height="480" />

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/sxj3.png" align="left" width="860" height="640" />

# %% [markdown]
#  <br/>

# %% [markdown]
# ===================================================================
#
# 数学教辅碎片中遇到的主要问题是无法一些 **公式** 或者 ** 特殊数学符号** 的识别
#
# 如*根式*、*分式*、*乘方*、*大括号* 等
#
# 这样说来，对于数学教辅来说，
#
# 小学部分的应该没什么问题，可能主要是识别文字，和一些简单的式子
#
# 高中部分，则会有一些无法识别的公式或者特殊符号则需要人为去修改录入

# %% [markdown]
# -------------------------------

# %% [markdown]
# ## 总结

# %% [markdown]
# <p>通过上面各种不同场景的分析，我觉得以上两款OCR确实能很好地满足我们识别的需要，他们在特定的使用场景里都有着不错的表现。</p>

# %% [markdown]
# ⒈ 针对英语教材点读的Tesseract-OCR，人工划分区域的多块识别。未训练过已能达到较高的识别率，后续如果需要继续提高识别率，我们可以针对教材的特定字体进行训练。

# %% [markdown]
# ⒉ 针对语文教材单页、教辅碎片的Baidu-OCR识别，由于大多是规整文本，可以进行整页识别，识别率非常可观，问题在于字数多，所以识别后的检查比较头疼。

# %% [markdown]
# ⒊ 针对英语、数学教辅碎片的Baidu-OCR识别，首先对于返回结果的优化，使得对英语题干部分识别效果好了很多。总体的识别率都非常可以，但是还是存在以下一些可能通过技术手段无法很好解决的问题：
#
# > ① 一些包含图片，同一水平线有多块不同文本区域的碎片
#
# > ② 英语的选择题部分： 答题下划线和括号、选项无法很好识别
#
# > ③ 高年级的数学，有一些公式和特殊符号无法很好识别
#
# 以上这些情况，可能就需要人工去进行修改、干预了

# %% [markdown]
# 总的来说，Baidu-OCR这款产品确实很强大，定价也很便宜；
#
# 对比ABBYY、汉王、阿里-OCR等产品，他都有着更好的表现；
#
# 相信如果能快点投入到我们录题的使用中，肯定能很好地提高效率。

# %% [markdown]
# ---

# %% [markdown]
# 附测试地址：  http://192.168.20.95:8000/polls

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/polls.png" align="left" />

# %% [markdown]
# Select Area - 选择矩形区域，只需要在起点左键一下，终点左键完成选取
#
# Edit - 此模式下，可编辑已经创建的矩形区域
#
# Clear - 清空所有矩形区域
#
# New Image - 打开一个新图片
#
# OCR - 使用Tesseract-OCR的原始英文包 eng 需要选择区域
#
# 中文-OCR - 使用Tesseract-OCR的原始中文包 chi-sim 需要选择区域
#
# 百度-OCR - 使用Baidu-OCR api 对 整张图片 进行识别
#
# =====================================================================

# %% [markdown]
# <img src="http://nbviewer.jupyter.org/github/Jinan12f3/my_test/blob/master/image/polls2.png" align="left" />
